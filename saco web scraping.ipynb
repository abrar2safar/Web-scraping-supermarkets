# %% [markdown]
# # Saco

# %%
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
from selenium import webdriver
import numpy as np
from scipy import  stats
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
driver = webdriver.Chrome('/Users/abrar2afar/Documents/chromedriver-2')


driver.get('https://www.saco-ksa.com/electrical-appliances.html')

sleep(5)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
product_names = []
product_prices = []

product_names.append(soup.find_all('strong'))
product_prices.append(soup.find_all('a', attrs={'price-wrapper '}))

product_names.append(soup.find_all('a'))
product_prices.append(soup.find_all('span', attrs={'class':'price-wrapper '}))



for i in range(2,100):
   
    driver.get(f'https://www.saco-ksa.com/electrical-appliances.html?p=s{i}')

    sleep(5)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
print(f'finish #{i}')
driver.close()
# Out:
# finish #99

# %%
for i in soup.find_all(name='div',attrs={'class':"product details product-item-details"}):
        item_name.append(i.find('strong', class_="product name product-item-name").text)
        
for i in soup.find_all(name='div',attrs={'class':"price-box price-final_price"}):
         item_price.append(i.find('span', class_="price").text)

# %%
item_price
# Out:
# ['\n\nر س \u200f\xa0119.75 \n',
#  '\n\nر س \u200f\xa0129.75 \n',
#  '\n\nر س \u200f\xa0169.75 \n',
#  '\n\nر س \u200f\xa0129.75 \n',
#  '\n\nر س \u200f\xa042.75 \n',
#  '\n\nر س \u200f\xa089.75 \n',
#  '\n\nر س \u200f\xa0139.75 \n',
#  '\n\nر س \u200f\xa0525.00 \n',
#  '\n\nر س \u200f\xa0379.75 \n',
#  '\n\nر س \u200f\xa0189.75 \n',
#  '\n\nر س \u200f\xa0109.75 \n',
#  '\n\nر س \u200f\xa0169.75 \n',
#  '\n\nر س \u200f\xa0739.00 \n',
#  '\n\nر س \u200f\xa0219.75 \n',
#  '\n\nر س \u200f\xa0199.75 \n',
#  '\n\nر س \u200f\xa0199.75 \n',
#  '\n\nر س \u200f\xa032.75 \n',
#  '\n\nر س \u200f\xa049.75 \n',
#  '\n\nر س \u200f\xa0269.75 \n',
#  '\n\nر س \u200f\xa032.75 \n',
#  '\n\nر س \u200f\xa089.75 \n',
#  '\n\nر س \u200f\xa0139.75 \n',
#  '\n\nر س \u200f\xa0679.00 \n',
#  '\n\nر س \u200f\xa089.75 \n',
#  '\n\nر س \u200f\xa0779.00 \n',
#  '\n\nر س \u200f\xa021.75 \n',
#  '\n\nر س \u200f\xa0379.75 \n',
#  '\n\nر س \u200f\xa0239.75 \n',
#  '\n\nر س \u200f\xa0699.00 \n',
# ...

# %%
item_name
# Out:
# ['\n\n                                خلاط يدوي ٥٥٠واط فيلبس                            \n',
#  '\n\n                                مطحنة بن 150 جرام ، وعاء ستانلستيل 220                            \n',
#  '\n\n                                جهاز تحضير الوافل والخبز الفرنسي                            \n',
#  '\n\n                                صانعة بسكويت الوافل  ريترو احمر 750 واط                            \n',
#  '\n\n                                كبسولات كابتشينو ١٦ حبة للعلبة                            \n',
#  '\n\n                                مكواة بسطح سهل الانزلاق ١٢٠٠واط                            \n',
#  '\n\n                                محمصة توست شريحتين 800واط معدنية فيليبس                            \n',
#  '\n\n                                مكواة بخارية ٢.٤لتر2000-1600واط مع مكواة                            \n',
#  '\n\n                                محضرة القهوة التركية ٤أكواب أحمر/أسود                            \n',
# ...

# %%
while(True):
    try:
        #scroll down to bottom of page
        # Get scroll height
        last_height = driver.execute_script("return document.body.scrollHeight")
        # print ('first last height',last_height)  # print last height for debugging purposes
        while True:
            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            # Wait to scroll the page down
            sleep(5)

            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")

            # print ('new height',new_height)  # print new height after scroll for debugging purposes

        if new_height == last_height:
            break
        last_height = new_height
    except:
        print('finish')
        break
# Out:
# finish

# %%
soup
# Out:
# <html lang="ar-SA"><head>
# ...

# %%
soup.find_all('div', attrs={'Cart__CartItems-d6bog0-17 dXMpiD cart-items'})
# Out:
# [<div class="Cart__CartItems-d6bog0-17 dXMpiD cart-items" dir="ltr"><div class="Carousel__StyledCarouselWrapper-sc-9ouat3-0 kHNwHF horizontal-carousel" dir="ltr"><div class="Carousel__CarouselContainer-sc-9ouat3-2 logBrv"><div class="elements-div content-not-overflow" data-testid="carousel" style="position:relative;left:0px;transition:left ease-out 0.45s"></div></div></div></div>]
